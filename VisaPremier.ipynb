# %% [markdown]
# # **Projet Data : Score d’appétence de la carte visa premier**

# %% [markdown]
# ### **La description du dataset**
# Il s’agit d’une base de données décrivant les clients d’une banque et
# leurs comportements (mouvements, soldes des différents comptes). La variable à expliquer Y est
# la variable binaire « Possession de la carte Visa Premier ».
# Les données sont composées de 1073 clients d'une banque décrits par 47 variables concernant leurs avoirs, et utilisations de leurs comptes.

# %% [markdown]
# ### **La préparation du dataset (sur Excel)**
# 1- On a copié  le dataset du fichier texte dans un fichier Excel (.csv)
#
# 2- On a supprimé quelques lignes avec des valeurs manquantes (qui contient "." et "F." comme valeure).
#
# 3- On a supprimé qulque colonnes qui contient que des valaurs null comme(nbimpaye,mtrejet).
#
# 4-Et pour la varialbe ‘matricul’, c’est id, donc ce n’est pas
# une vraie variables.
#
# 5-Pour les deux variables sexe et cartevp il exite leur double codé en (0/1) donc on va laisser les deux variable codés sexer (0='Shom'/1='Sfem')  et cartevpr (0='Cnon'/1='Coui').

# %% [markdown]
# ### **Importation des librairies**

# %%
#libraries 
import numpy as np
import pandas as pd
import random as rd
import seaborn as sb
import matplotlib.pyplot as plt
#metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import plot_confusion_matrix
# %matplotlib inline
#algorithms
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis as QDA
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.naive_bayes import BernoulliNB
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
#preprocessing 
from sklearn.preprocessing import StandardScaler
#model_selection
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ### **La lecture du dateset finale**

# %%
D=pd.read_csv("VisaPremier.csv",sep=';')

# %% [markdown]
# ### **Analyse Univariée**

# %%
#Descreption de datastet
D.describe()
# Out:
#          departem     ptvente         age  ...       sexer    cartevpr    nbjdebit
# count  722.000000  722.000000  722.000000  ...  722.000000  722.000000  722.000000
# mean    41.326870    1.617729   42.774238  ...    0.322715    0.425208   14.479224
# std     19.284528    1.020248   11.247573  ...    0.467839    0.494717   24.772031
# min      6.000000    1.000000   19.000000  ...    0.000000    0.000000    0.000000
# 25%     31.000000    1.000000   34.000000  ...    0.000000    0.000000    0.000000
# 50%     31.000000    1.000000   43.000000  ...    0.000000    0.000000    1.000000
# 75%     64.000000    2.000000   52.000000  ...    1.000000    1.000000   16.000000
# max     97.000000    7.000000   65.000000  ...    1.000000    1.000000  114.000000
#
# [8 rows x 40 columns]

# %%
#La descreption de la classe "cartevpr"
sb.countplot(x=D['cartevpr'],data=D)

# %%
#La description de la classe "cartevpr" par rapport le sexe 
sb.countplot(x=D['cartevpr'],hue='sexer',data=D,palette='RdBu_r')

# %% [markdown]
# ### **Analyse bivariée**

# %%
corr = D.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
# #T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row0_col0,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row1_col1,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row2_col2,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row3_col3,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row4_col4,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row5_col5,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row6_col6,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row7_col7,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row8_col8,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row9_col9,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row10_col10,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row11_col11,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row12_col12,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row13_col13,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row14_col14,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row15_col15,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row16_col16,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row17_col17,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row18_col18,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row19_col19,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row20_col20,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row21_col21,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row22_col22,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row23_col23,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row24_col24,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row25_col25,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row26_col26,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row27_col27,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row28_col28,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row29_col29,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row30_col30,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row30_col31,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row31_col30,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row31_col31,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row32_col32,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row33_col33,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row34_col34,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row35_col35,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row36_col36,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row37_col37,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row38_col38,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row39_col39{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row0_col1,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row3_col10,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row6_col19,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row7_col2,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row9_col4,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row11_col24,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row12_col34,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row18_col8,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row19_col34,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row20_col13,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row22_col26,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row23_col2,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row27_col35,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row28_col6,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row32_col23,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row35_col16,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row35_col27,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row38_col27{
#             background-color:  #6b8df0;
#             color:  #000000;
#         }#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row0_col2,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row2_col11,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row3_col1,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row3_col9,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row4_col29,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row5_col9,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row6_col0,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row7_col14,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row7_col23,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row8_col0,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row9_col24,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row10_col18,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row15_col26,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row16_col5,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row16_col21,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row16_col28,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row21_col14,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row21_col36,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row26_col14,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row28_col23,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row32_col36,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row33_col0,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row36_col14,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row38_col7{
#             background-color:  #516ddb;
#             color:  #000000;
#         }#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row0_col3,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row0_col17,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row3_col0,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row3_col30,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row3_col31,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row4_col30,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row4_col31,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row9_col29,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row10_col29,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row11_col14,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row13_col29,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row17_col9,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row17_col21,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row17_col29,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row19_col1,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row19_col5,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row19_col28,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row26_col29,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row27_col28,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row29_col11,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row30_col11,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row31_col11,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row34_col0,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row34_col1,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row34_col25,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row36_col28,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row38_col0{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row0_col4,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row0_col19,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row0_col36,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row2_col28,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row2_col29,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row4_col0,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row12_col39,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row15_col1,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row15_col14,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row24_col30,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row24_col31,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row32_col1,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row32_col26,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row32_col27,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row33_col19,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row34_col2,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row34_col8,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row34_col11,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row34_col15,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row34_col17,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row34_col18,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row34_col20,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row34_col22,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row34_col23,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row34_col24,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row34_col26,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row34_col27,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row34_col32,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row34_col35,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row34_col36,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row37_col3,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row37_col5,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row37_col7,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row37_col8,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row37_col9,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row37_col10,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row37_col13,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row37_col16,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row37_col33,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002row37_col35,#T_bdec7686_75b9_11eb_b4c1_0242ac1c0002ro

# %% [markdown]
# ### **Trouver et remplacer les variables catégorielles**
# On code les variables Catégorielles avec des nombres
# *  codeqlt : { A=1 , B=2 , C=3 , D=4 ,  E=5 }
# *  sitfamil : { Fmar=1 , Fcel=2 , Fdiv=3 , Fsep=4 , Fveu=5 , Fuli=6 }
# *   csp : { Pagri=1 , Pcad=2 , Psan=3 , Pouv=4 , Pemp=5 ,  Part=6 , Pret=7 }

# %%
#codeqlt
re_code= {"codeqlt":{"A":1,"B":2,"C":3,"D":4,"E":5} ,
          "sitfamil":{"Fmar":1,"Fcel":2,"Fdiv":3,"Fsep":4,"Fveu":5,"Fuli":6},
          "csp":{"Pagri":1,"Pcad":2,"Psan":3,"Pouv":4,"Pemp":5,"Part":6,"Pret":7}
          }
D=D.replace(re_code)

# %% [markdown]
# ### **One-Hot Encoding**
# On va utiliser une astuce qui convertit une colonne de donnée catégorielles (les variables categorielles qu'on a codé) en plusieurs colonnes de valeurs binaires

# %%
D=pd.get_dummies(D,columns=['sitfamil','csp','codeqlt'])

# %% [markdown]
# ### **Extraction des échantillons apprentissage et test**

# %%
y=D["cartevpr"]
D=D.drop(['cartevpr','moycred3', 'mtbon', 'engageml'],axis=1)
rd_seed=50 #
npop=len(D)
D_trn,D_tst,y_trn,y_tst=train_test_split(D,y,test_size=150,random_state=rd_seed)

# %% [markdown]
# ### **Normalisation avec StandarScaler**

# %%
sc = StandardScaler()
D_trn = sc.fit_transform(D_trn)
D_tst = sc.transform(D_tst)

# %% [markdown]
# ## **Appliquer les différents classificateurs**

# %% [markdown]
# ### **Bayesien Naïf**

# %%
clf_nb = BernoulliNB()
clf_nb.fit(D_trn, y_trn)
y_pred = clf_nb.predict(D_tst)
nb_ac=accuracy_score(y_tst,y_pred)
nb_f1=f1_score(y_tst,y_pred)
print("Accuracy = "+str(nb_ac),"F1_measure = "+str(nb_f1))
# Out:
# Accuracy = 0.7 F1_measure = 0.64

# %%
#confusion matrix Bayesien naif
fig, ax = plt.subplots(figsize=(3,3))
plot_confusion_matrix(clf_nb,D_tst,y_tst,display_labels=["Cnon", "Coui"],ax=ax)

# %% [markdown]
# ### **KNN**

# %%
from sklearn.neighbors import KNeighborsClassifier
clf_knn = KNeighborsClassifier(n_neighbors=3)
clf_knn.fit(D_trn, y_trn)
y_pred=clf_knn.predict(D_tst)
knn_ac=accuracy_score(y_tst,y_pred)
knn_f1=f1_score(y_tst,y_pred)
print("Accuracy = "+str(knn_ac),"F1_measure = "+str(knn_f1))
# Out:
# Accuracy = 0.7466666666666667 F1_measure = 0.6481481481481481

# %%
#confusion matrix KNN
fig, ax = plt.subplots(figsize=(3,3)) 
plot_confusion_matrix(clf_knn,D_tst,y_tst,display_labels=["Cnon", "Coui"],ax=ax)

# %% [markdown]
# ### **LDA**

# %%
clf_lda = LDA()
clf_lda.fit(D_trn, y_trn)
y_pred = clf_lda.predict(D_tst)
lda_ac=accuracy_score(y_tst,y_pred)
lda_f1=f1_score(y_tst,y_pred)
print("Accuracy = "+str(lda_ac),"F1_measure = "+str(lda_f1))
# Out:
# Accuracy = 0.8066666666666666 F1_measure = 0.7238095238095238

# %%
#confusion matrix LDA 
fig, ax = plt.subplots(figsize=(3,3)) #plot size 
plot_confusion_matrix(clf_lda,D_tst,y_tst,display_labels=["Cnon", "Coui"],ax=ax)

# %% [markdown]
# ### **QDA**

# %%
clf_qda = QDA()
clf_qda.fit(D_trn, y_trn)
y_pred = clf_qda.predict(D_tst)
qda_ac=accuracy_score(y_tst,y_pred)
qda_f1=f1_score(y_tst,y_pred)
print("Accuracy = "+str(qda_ac),"F1_measure = "+str(qda_f1))
# Out:
# Accuracy = 0.7 F1_measure = 0.5714285714285714
# /usr/local/lib/python3.6/dist-packages/sklearn/discriminant_analysis.py:691: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")

# %%
#confusion matrix QDA
fig, ax = plt.subplots(figsize=(3,3)) #plot size 
plot_confusion_matrix(clf_qda,D_tst,y_tst,display_labels=["Cnon", "Coui"],ax=ax)

# %% [markdown]
# ### **Linear SVM**

# %%
clf_lsvm=svm.LinearSVC()
clf_lsvm.fit(D_trn,y_trn)
y_pred = clf_lsvm.predict(D_tst) 
l_svm_ac=accuracy_score(y_tst,y_pred)
l_svm_f1=f1_score(y_tst,y_pred)
print("Accuracy = "+str(l_svm_ac),"F1_measure = "+str(l_svm_f1))
# Out:
# Accuracy = 0.82 F1_measure = 0.7610619469026549
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
#confusion matrix Linear SVM
fig, ax = plt.subplots(figsize=(3,3)) #plot size 
plot_confusion_matrix(clf_lsvm,D_tst,y_tst,display_labels=["Cnon", "Coui"],ax=ax)

# %% [markdown]
# ### **Non Linear SVM**

# %% [markdown]
# **Optimiser les paramètres avec GridSearch**

# %%
param_grid = [
  {'C': [1, 10, 100, 1000], 
   'gamma': [0.001, 0.0001], 
   'kernel': ['rbf']},
 ] #kernel - rbf

optimal_params = GridSearchCV(svm.SVC(),param_grid,cv=5,verbose=0)

optimal_params.fit(D_trn, y_trn) #fit

print(optimal_params.best_params_)
# Out:
# {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}

# %% [markdown]
# **Tester le SVM finale**

# %%
clf_svm=svm.SVC(C=100,gamma=0.001,kernel='rbf')
clf_svm.fit(D_trn,y_trn)
y_pred = clf_svm.predict(D_tst) 
nl_svm_ac=accuracy_score(y_tst,y_pred)
nl_svm_f1=f1_score(y_tst,y_pred)
print("Accuracy = "+str(nl_svm_ac),"F1_measure = "+str(nl_svm_f1))
# Out:
# Accuracy = 0.8266666666666667 F1_measure = 0.7719298245614035

# %%
#confusion matrix Linear SVM
fig, ax = plt.subplots(figsize=(3,3)) #plot size 
plot_confusion_matrix(clf_svm,D_tst,y_tst,display_labels=["Cnon", "Coui"],ax=ax)

# %% [markdown]
# ### **Régression Logistique**

# %%
clf_lr= LogisticRegression()
clf_lr.fit(D_trn,y_trn)
y_pred=clf_lr.predict(D_tst)
lr_ac=accuracy_score(y_tst,y_pred)
lr_f1=f1_score(y_tst,y_pred)
print("Accuracy = "+str(lr_ac),"F1_measure = "+str(lr_f1))
# Out:
# Accuracy = 0.8066666666666666 F1_measure = 0.7387387387387386

# %%
#confusion matrix Regression logistique
fig, ax = plt.subplots(figsize=(3,3)) #plot size 
plot_confusion_matrix(clf_lr,D_tst,y_tst,display_labels=["Cnon", "Coui"],ax=ax)

# %% [markdown]
# ### **CART**

# %%
clf_cart = DecisionTreeClassifier()
clf_cart.fit(D_trn, y_trn)
y_pred = clf_cart.predict(D_tst)
cart_ac=accuracy_score(y_tst,y_pred)
cart_f1=f1_score(y_tst,y_pred)
print("Accuracy = "+str(cart_ac),"F1_measure = "+str(cart_f1))
# Out:
# Accuracy = 0.8466666666666667 F1_measure = 0.8099173553719008

# %%
#confusion matrix Linear SVM
fig, ax = plt.subplots(figsize=(3,3)) #plot size 
plot_confusion_matrix(clf_cart,D_tst,y_tst,display_labels=["Cnon", "Coui"],ax=ax)

# %% [markdown]
# ### **Random Forest**

# %%
clf_rf = RandomForestClassifier(max_depth=21, random_state=0)
clf_rf.fit(D_trn, y_trn)
y_pred = clf_rf.predict(D_tst)
rf_ac=accuracy_score(y_tst,y_pred)
rf_f1=f1_score(y_tst,y_pred)
print("Accuracy = "+str(rf_ac),"F1_measure = "+str(rf_f1))
# Out:
# Accuracy = 0.8933333333333333 F1_measure = 0.864406779661017

# %%
#confusion matrix Random Forest
fig, ax = plt.subplots(figsize=(3,3)) #plot size 
plot_confusion_matrix(clf_rf,D_tst,y_tst,display_labels=["Cnon", "Coui"],ax=ax)

# %% [markdown]
# ## **Comparaison entre les méthodes**

# %%
results ={'Accuracy': [nb_ac*100,knn_ac*100,nl_svm_ac*100,l_svm_ac*100,lr_ac*100,cart_ac*100,rf_ac*100,lda_ac*100,qda_ac*100],
          'F1_mesure': [nb_f1*100,knn_f1*100,nl_svm_f1*100,l_svm_f1*100,lr_f1*100,cart_f1*100,rf_f1*100,lda_f1*100,qda_f1*100]}
index = ["Bayesien Naïf","KNN","Lineair SVM","Non Lineair SVM","Regression Logistique","CART","Random Forest","LDA","QDA"]
results =pd.DataFrame(results,index=index)

# %%
r=results.plot(kind='bar',title='Comparaison entre les modèles ',figsize=(19,8),color = ['darkslategrey', 'c'],rot=10,fontsize=15)
for p in r.patches:
    r.annotate(format(p.get_height(), '.1f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (2,8), 
                   textcoords = 'offset points',
                   fontsize=15)
